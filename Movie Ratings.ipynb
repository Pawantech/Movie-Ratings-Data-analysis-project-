# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\pawan\\Pictures\\jupyter files'

# %%
movies = pd.read_csv("Movie_Ratings.csv")

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movies
# Out:
#                                    Film      Genre  CriticRating  \
# 0                 (500) Days of Summer      Comedy            87
# 1                           10,000 B.C.  Adventure             9
# 2                            12 Rounds      Action            30
# 3                             127 Hours  Adventure            93
# 4                             17 Again      Comedy            55
# 5                                  2012     Action            39
# 6                            27 Dresses     Comedy            40
# 7                      30 Days of Night     Horror            50
# 8                    30 Minutes or Less     Comedy            43
# 9                                 50/50     Comedy            93
# 10                           88 Minutes      Drama             5
# 11                   A Dangerous Method      Drama            79
# 12            A Nightmare on Elm Street     Horror            13
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()             # as we can notice, the column Year doesn't make any sense for mean and other functions and thats a problem.
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
# changing data types
movies.Film = movies.Film.astype("category")
movies.info()                               # now you can notice Film data type is changed in category
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
# getting unique categories in columns
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating')

# %%
j2 = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind='hex')

# %% [markdown]
# ---

# %%
###########################Histograms#################################

# %%
sns.set_style('darkgrid')
h1 = sns.distplot(movies.AudienceRating, bins=16)

# %%
h2 = sns.distplot(movies.CriticRating, bins=16)

# %%
h3 = plt.hist(movies.AudienceRating, bins=16 )

# %%
h3 = plt.hist(movies.CriticRating, bins=16 )

# %%
movies.Genre.unique
# Out:
# <bound method Series.unique of 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
# 5         Action
# 6         Comedy
# 7         Horror
# 8         Comedy
# 9         Comedy
# 10         Drama
# 11         Drama
# 12        Horror
# 13         Drama
# 14        Comedy
# 15        Action
# 16       Romance
# 17        Comedy
# 18         Drama
# 19     Adventure
# 20        Horror
# 21     Adventure
# 22        Comedy
# 23         Drama
# 24     Adventure
# 25      Thriller
# 26         Drama
# 27         Drama
# 28        Horror
# 29        Action
#          ...
# 529        Drama
# 530       Action
# 531       Action
# 532        Drama
# 533       Comedy
# 534        Drama
# 535       Comedy
# 536       Comedy
# 537       Comedy
# 538       Comedy
# 539       Comedy
# 540    Adventure
# 541        Drama
# 542       Action
# 543       Comedy
# 544       Comedy
# 545        Drama
# 546       Action
# 547       Action
# 548    Adventure
# ...

# %%
#analysis of different fields in single chart
#step 1
movies.Genre == 'Action'
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29      True
#        ...
# 529    False
# 530     True
# 531     True
# 532    False
# 533    False
# 534    False
# 535    False
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# 541    False
# 542     True
# 543    False
# 544    False
# 545    False
# 546     True
# 547     True
# 548    False
# 549    False
# 550    False
# 551    False
# 552    False
# 553    False
# 554    False
# 555    False
# 556    False
# 557     True
# 558    False
# Name: Genre, Length: 559, dtype: bool

# %%
#step2
movies[movies.Genre == 'Action']
# Out:
#                                           Film   Genre  CriticRating  \
# 2                                   12 Rounds   Action            30
# 5                                         2012  Action            39
# 15                                   Abduction  Action             4
# 29                                   Appaloosa  Action            77
# 30                                    Armored   Action            40
# 33                                     Avatar   Action            83
# 36                                Babylon A.D.  Action             7
# 39                           Bangkok Dangerous  Action             9
# 40                         Battle: Los Angeles  Action            35
# 45                                     Beowulf  Action            71
# 49                                Body of Lies  Action            53
# 52                           Brooklyn's Finest  Action            42
# 58          Captain America: The First Avenger  Action            78
# ...

# %%
#step 3
movies[movies.Genre == 'Action'].BudgetMillions
# Out:
# 2       20
# 5      200
# 15      35
# 29      20
# 30      20
# 33     237
# 36      45
# 39      45
# 40      70
# 45     150
# 49      68
# 52      17
# 58     140
# 60      85
# 63      40
# 66     125
# 67      25
# 69      40
# 70      90
# 73      30
# 76     163
# 77      13
# 81      25
# 83      20
# 86      45
# 94      30
# 98      33
# 101     75
# 102     30
# 106     45
#       ...
# 433    138
# 435     50
# 439     40
# 441     80
# 443    150
# 448     25
# 451     40
# 454    145
# 458    100
# 472    150
# 473      6
# 474      0
# 477    100
# 479     75
# 493    150
# 495     35
# 499    150
# 500    195
# 501    210
# 502     30
# 504    170
# 512     35
# 514     95
# 528     75
# 530     25
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: BudgetMillions, Length: 154, dtype: int64

# %%
#step 4
plt.hist(movies[movies.Genre=='Action'].BudgetMillions, bins = 15)
# Out:
# (array([ 9., 39., 24., 13., 16.,  9.,  8., 14.,  5.,  4.,  8.,  2.,  2.,
#          0.,  1.]),
#  array([  0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180., 200.,
#         220., 240., 260., 280., 300.]),
#  <a list of 15 Patch objects>)

# %%
#step 5
plt.hist(movies[movies.Genre=='Action'].BudgetMillions, bins = 15)
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions, bins = 15)

plt.show()

# %%
#above approach is not good as the bars are overlapping. Therefore

plt.hist([movies[movies.Genre=='Action'].BudgetMillions,
          movies[movies.Genre=='Drama'].BudgetMillions], bins = 15)
plt.show()

# %%
#another way
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,
          movies[movies.Genre=='Drama'].BudgetMillions], bins = 15, stacked = True)
plt.show()

# %%
list1 =list()
mylabels= list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillions)
    mylabels.append(gen)
h = plt.hist(list1, bins= 30, stacked=True, rwidth=1, label=mylabels )
plt.legend()
plt.show()

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
vis1= sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', fit_reg=False, hue= 'Genre', size= 6, aspect=1)

# %%
########################### KDE plot #####################

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade="True")

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade="True",shade_lowest = "False",cmap='Reds')

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating,cmap='Reds')

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade="True",shade_lowest = "False",cmap='Reds')
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating,cmap='Reds')

# %%
####################### Working with Subplots ##########################

# %%
import matplotlib.pyplot as plt                           #Refreshing
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Audience Ratings
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,size= 5)

# %%
#Critics Ratings
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)

# %%
#step1
f,ax=plt.subplots(1,2)

# %%
#step2
f,ax=plt.subplots(1,2)
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,size= 5)
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)
#both comes in single field, avoid that

# %%
#step 4
f,axes=plt.subplots(1,2, figsize = (12,6), sharey=True)
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,size= 5, ax=axes[0])
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[1])

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DF26796400>,
# ...
#       dtype=object)

# %%
############## boxplot #############
b1 = sns.boxplot(data=movies, x='Genre', y='CriticRating')

# %%
b1 = sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
#Violin plot
b1 = sns.violinplot(data=movies, x='Genre', y='CriticRating')

# %%
b1 = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
######## Facet grid #############
g = sns.FacetGrid(movies, row='Genre', col = 'Year', hue='Genre')

# %%
#using the function in g.map()
#making use of the func,       plt.scatter,movies.CriticRating, movies.AudienceRating

# %%
g = sns.FacetGrid(movies, row='Genre', col = 'Year', hue='Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
# can populate with any function
g = sns.FacetGrid(movies, row='Genre', col = 'Year', hue='Genre')
g = g.map(plt.hist, 'CriticRating')

# %%
g = sns.FacetGrid(movies, row='Genre', col = 'Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor = 'black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws)
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c="grey", ls="--")
g.add_legend()
plt.show()

# %% [markdown]
# # Challenge for Advance Visualisation Section

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\pawan\\Pictures\\jupyter files'

# %%
import pandas as pd

# %%
challenge = pd.read_csv('C:\\Users\\pawan\\Pictures\\jupyter files\\Movie_Challenge.csv', encoding='latin1')

# %%
challenge.head()
# Out:
#   Day of Week                 Director   Genre        Movie Title  \
# 0      Friday                Brad Bird  action       Tomorrowland
# 1      Friday              Scott Waugh  action     Need for Speed
# 2      Friday           Patrick Hughes  action  The Expendables 3
# 3      Friday  Phil Lord, Chris Miller  comedy     21 Jump Street
# 4      Friday          Roland Emmerich  action   White House Down
#
#   Release Date               Studio Adjusted Gross ($mill)  Budget ($mill)  \
# 0   22/05/2015  Buena Vista Studios                  202.1           170.0
# 1   14/03/2014  Buena Vista Studios                  204.2            66.0
# 2   15/08/2014            Lionsgate                  207.1           100.0
# 3   16/03/2012                 Sony                  208.8            42.0
# 4   28/06/2013                 Sony                  209.7           150.0
#
#   Gross ($mill)  IMDb Rating  MovieLens Rating Overseas ($mill)  Overseas%  \
# ...

# %%
len(challenge)
# Out:
# 608

# %%
challenge.describe()
# Out:
#        Budget ($mill)  IMDb Rating  MovieLens Rating   Overseas%  \
# count      608.000000   608.000000        608.000000  608.000000
# mean        92.467928     6.923849          3.340378   57.698849
# std         59.421407     0.925890          0.454071   12.334237
# min          0.600000     3.600000          1.490000   17.200000
# 25%         45.000000     6.375000          3.037500   49.900000
# 50%         80.000000     6.900000          3.365000   58.200000
# 75%        130.000000     7.600000          3.672500   66.300000
# max        300.000000     9.200000          4.500000  100.000000
#
#             Profit%  Runtime (min)  US ($mill)  Gross % US
# count    608.000000     608.000000  608.000000  608.000000
# mean     719.278783     117.781250  167.135197   42.301151
# std     1942.807248      23.179122   92.465903   12.334237
# min        7.700000      30.000000    0.000000    0.000000
# 25%      201.850000     100.000000  106.950000   33.700000
# ...

# %%
challenge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
# Day of Week               608 non-null object
# Director                  608 non-null object
# Genre                     608 non-null object
# Movie Title               608 non-null object
# Release Date              608 non-null object
# Studio                    608 non-null object
# Adjusted Gross ($mill)    608 non-null object
# Budget ($mill)            608 non-null float64
# Gross ($mill)             608 non-null object
# IMDb Rating               608 non-null float64
# MovieLens Rating          608 non-null float64
# Overseas ($mill)          608 non-null object
# Overseas%                 608 non-null float64
# Profit ($mill)            608 non-null object
# Profit%                   608 non-null float64
# Runtime (min)             608 non-null int64
# US ($mill)                608 non-null float64
# Gross % US                608 non-null float64
# ...

# %%
sns.factorplot(data=challenge, x='Day of Week', kind='count', size =10)
